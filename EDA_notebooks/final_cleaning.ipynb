# %%
import pandas as pd

df = pd.read_csv('datasets/ncaa_d1_player_deltas.csv')

df
# Out:
#       Unnamed: 0  index       conference  \
# 0              0      0      Independent
# 1              1      1  Atlantic Hockey
# 2              2      2          Big Ten
# 3              3      3             CCHA
# 4              4      4      Independent
# ...          ...    ...              ...
# 1543        1543   1543             NCHC
# 1544        1544   1544  Atlantic Hockey
# 1545        1545   1545      Hockey East
# 1546        1546   1546  Atlantic Hockey
# 1547        1547   1547      Hockey East
#
#                                            team           player position  \
# 0                    Stonehill College Skyhawks        Zach Aben        F
# 1           College of the Holy Cross Crusaders  Michael Abgrall        F
# 2                Ohio State University Buckeyes       Chris Able        D
# 3              Michigan Tech University Huskies     Ryan Abraham        F
# 4      University of Alaska Anchorage Seawolves    Logan Acheson        D
# ...

# %%
df = df.iloc[:, 2:]

df
# Out:
#            conference                                       team  \
# 0         Independent                 Stonehill College Skyhawks
# 1     Atlantic Hockey        College of the Holy Cross Crusaders
# 2             Big Ten             Ohio State University Buckeyes
# 3                CCHA           Michigan Tech University Huskies
# 4         Independent   University of Alaska Anchorage Seawolves
# ...               ...                                        ...
# 1543             NCHC  University of North Dakota Fighting Hawks
# 1544  Atlantic Hockey                         Army Black Knights
# 1545      Hockey East       University of New Hampshire Wildcats
# 1546  Atlantic Hockey         Robert Morris University Colonials
# 1547      Hockey East                            UMass Minutemen
#
#                player position toi_(min)  successful_oz_offensive_touches  \
# 0           Zach Aben        F    135:14                         1.325179
# ...

# %%
df.to_csv("datasets/ncaa_d1_player_deltas_cleaned.csv", index=False)
